# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
train = pd.read_csv('Grading of the students in the exam (IPE101) raw.csv')

# %%
train.head()
# Out:
#    Roll CT-1 (Marks: 20) CT-2 (Marks: 20) CT-3 (Marks: 20) CT-4 (Marks: 20)  \
# 0   2.0             12.5               15               14               18
# 1   3.0                9               10               17               11
# 2   4.0               10             15.5             12.5              6.5
# 3   5.0               14               14               18                0
# 4   6.0             14.5             15.5               15             15.5
#
#   Class Test (Total of best 3, Marks: 60) Attendance (Marks: 15)  \
# 0                                      47                     15
# 1                                      38                     15
# 2                                      38                     15
# 3                                      46                     15
# 4                                      46                     15
#
#   Observation (Marks: 15) Total (Marks: 90)  Exam Mark (105)  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 54 entries, 0 to 62
# Data columns (total 12 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Roll                                     54 non-null     float64
#  1   CT-1 (Marks: 20)                         54 non-null     str
#  2   CT-2 (Marks: 20)                         54 non-null     str
#  3   CT-3 (Marks: 20)                         54 non-null     str
#  4   CT-4 (Marks: 20)                         54 non-null     str
#  5   Class Test (Total of best 3, Marks: 60)  54 non-null     str
#  6   Attendance (Marks: 15)                   54 non-null     str
#  7   Observation (Marks: 15)                  54 non-null     str
#  8   Total (Marks: 90)                        54 non-null     str
#  9   Exam Mark (105)                          54 non-null     float64
#  10  Exam Mark (105).1                        54 non-null     float64
# ...

# %%
train.describe()
# Out:
#             Roll  Exam Mark (105)  Exam Mark (105).1  Mark total 300
# count  54.000000        54.000000          54.000000       54.000000
# mean   32.500000        35.972222          57.537037      165.324074
# std    18.827669        17.312995          20.441092       35.735290
# min     2.000000         3.000000           2.000000       52.000000
# 25%    15.250000        26.000000          43.250000      139.750000
# 50%    31.500000        35.500000          59.750000      165.250000
# 75%    47.750000        48.000000          73.000000      184.125000
# max    64.000000        89.000000          97.000000      244.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train.isnull()
# Out:
#      Roll  CT-1 (Marks: 20)  CT-2 (Marks: 20)  CT-3 (Marks: 20)  \
# 0   False             False             False             False
# 1   False             False             False             False
# 2   False             False             False             False
# 3   False             False             False             False
# 4   False             False             False             False
# 5   False             False             False             False
# 6   False             False             False             False
# 7   False             False             False             False
# 8   False             False             False             False
# 9   False             False             False             False
# 10  False             False             False             False
# 11  False             False             False             False
# 12  False             False             False             False
# 13  False             False             False             False
# ...

# %%
train.isnull().sum()
# Out:
# Roll                                       0
# CT-1 (Marks: 20)                           0
# CT-2 (Marks: 20)                           0
# CT-3 (Marks: 20)                           0
# CT-4 (Marks: 20)                           0
# Class Test (Total of best 3, Marks: 60)    0
# Attendance (Marks: 15)                     0
# Observation (Marks: 15)                    0
# Total (Marks: 90)                          0
# Exam Mark (105)                            0
# Exam Mark (105).1                          0
# Mark total 300                             0
# dtype: int64

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='summer')
# Out:
# <Axes: >

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=True,cmap='summer')
# Out:
# <Axes: >

# %%
train['Mark total 300'].hist(bins=30)
# Out:
# <Axes: >

# %%
sns.kdeplot(train['Mark total 300'], shade=True)
# Out:
# <Axes: xlabel='Mark total 300', ylabel='Density'>

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(data=train['Mark total 300'])
# Out:
# <Axes: ylabel='Mark total 300'>

# %% [markdown]
# ## Data Cleaning

# %%
train['Mark total 300'].mean()
# Out:
# np.float64(165.32407407407408)

# %%
train = train.dropna()

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
train.head()
# Out:
#    Roll CT-1 (Marks: 20) CT-2 (Marks: 20) CT-3 (Marks: 20) CT-4 (Marks: 20)  \
# 0   2.0             12.5               15               14               18
# 1   3.0                9               10               17               11
# 2   4.0               10             15.5             12.5              6.5
# 3   5.0               14               14               18                0
# 4   6.0             14.5             15.5               15             15.5
#
#   Class Test (Total of best 3, Marks: 60) Attendance (Marks: 15)  \
# 0                                      47                     15
# 1                                      38                     15
# 2                                      38                     15
# 3                                      46                     15
# 4                                      46                     15
#
#   Observation (Marks: 15) Total (Marks: 90)  Exam Mark (105)  \
# ...

# %%
train['Mark total 300'].mode()
# Out:
# 0    133.5
# 1    159.5
# 2    180.5
# 3    225.0
# Name: Mark total 300, dtype: float64
